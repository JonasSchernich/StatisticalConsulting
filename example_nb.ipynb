# %% [markdown]
# # Example notebook: BaseModel and child classes

# %%
from new_structure.src.models.base_model import BaseSurvivalModel
from new_structure.src.models.rsf import RSFModel
from new_structure.src.models.cox import PenCoxModel
from new_structure.src.models.boosting import GBModel
from new_structure.src.utils import utils

import numpy as np 
import pandas as pd
from source.preprocessing import DataLoader 
from sklearn.preprocessing import StandardScaler
from sksurv.ensemble import RandomSurvivalForest, GradientBoostingSurvivalAnalysis
import os
base_path = os.path.dirname(os.getcwd())

# %%
# load the data
dl = DataLoader("C:/Users/laeti/OneDrive/Dokumente/LMU/StatisticalConsulting")
dl.load_all_data()

# %%
# prepare example data
intersection_exprs_df = pd.DataFrame(dl.intersection_data['exprs_intersect.csv'])
merged_pData_imputed = pd.DataFrame(dl.merged_pdata_imputed['merged_imputed_pData.csv'])

y = utils.create_surv_y(merged_pData_imputed['BCR_STATUS'], merged_pData_imputed['MONTH_TO_BCR'])
X = intersection_exprs_df

# %% [markdown]
# ## Generelles

# %% [markdown]
# Manche der Pipeline Steps, die der fit_model Funktion übergeben werden MÜSSEN auf eine bestimmte Art und Weise benannt werden:
# - Schritt zur feature selection: 'feat_sel'
# - Schritt zur Modellierung/zum Model: 'model'
#
# Die Schritte zur Datentransfromation (z.B. standard scaler etc.) müssen nicht speziell benannt werden

# %% [markdown]
# ## Beispiele

# %% [markdown]
# ### Gradient boosting

# %%
# instantiate GBModel, which inherits from BaseModel
gb = GBModel()

# %%
# create steps for sksurv pipeline, necessary to fit the model
pipe_steps_gb = [('gb', GradientBoostingSurvivalAnalysis())]
params_cv = {
        'gb__n_estimators': [2],
        'gb__learning_rate': [0.1],
        'gb__max_depth': [3]
    }

path = os.path.join(base_path, 'examples_new_struct')
gb.fit_model(X, y, fname= 'gb_example', path =  path, pipeline_steps = pipe_steps_gb, params_cv = params_cv, refit = True, save_model = True)
# Out:
# Fitting 9 folds for each of 1 candidates, totalling 9 fits
#
# Best parameters: {'gb__learning_rate': 0.1, 'gb__max_depth': 3, 'gb__n_estimators': 2}
#
# Cross-validation results:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      18.094693      1.193542         0.122473        0.039382
#
#    param_gb__learning_rate  param_gb__max_depth  param_gb__n_estimators  \
# 0                      0.1                    3                       2
#
#                                               params  split0_test_score  \
# 0  {'gb__learning_rate': 0.1, 'gb__max_depth': 3,...           0.614306
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.571788           0.476091           0.571704             0.7023
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.620368           0.843594           0.629852            0.60783
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.626426        0.095476                1
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 10
#       3 params_cv = {
#       4         'gb__n_estimators': [2],
#       5         'gb__learning_rate': [0.1],
#       6         'gb__max_depth': [3]
#       7     }
#       9 path = os.path.join(base_path, 'examples_new_struct')
# ---> 10 gb.fit_model(X, y, fname= 'gb_example', path =  path, pipeline_steps = pipe_steps_gb, params_cv = params_cv, refit = True, save_model = True)
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\new_structure\src\models\base_model.py:53, in BaseSurvivalModel.fit_model(self, X, y, fname, path, pipeline_steps, params_cv, params_feat_sel, refit, save_model)
#      50 print("\nCross-validation results:")
#      51 print(pd.DataFrame(gcv.cv_results_))
# ---> 53 self.save_csv_gcv(gcv, path, fname)
#      55 if refit:
#      56    best_model = gcv.best_estimator_
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\new_structure\src\models\base_model.py:95, in BaseSurvivalModel.save_csv_gcv(self, gcv, path, fname)
#      93 csv_path = os.path.join(path, fname)
#      94 cv_results = pd.DataFrame(gcv.cv_results_)
# ---> 95 cv_results.to_csv(csv_path)
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\laeti\OneDrive\Dokumente\LMU\StatisticalConsulting\.venv\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'c:\Users\laeti\OneDrive\Dokumente\LMU\examples_new_struct'

# %% [markdown]
# ## Deep Surv
# ##### Ich habe nochmal nen eigenen import gemacht. Die Cohorten für die cohortenweise CV bestimme ich extra und c-index mache ich auch extra im deep surv. Müssen wir dann noch zusammen führen.

# %%
def get_cohorts_from_index(index):
   cohort_names = [idx.split('.')[0] for idx in index]
   
   unique_cohorts = sorted(list(set(cohort_names)))
   cohort_to_id = {cohort: idx for idx, cohort in enumerate(unique_cohorts)}
   
   cohorts = np.array([cohort_to_id[cohort] for cohort in cohort_names])
   
   for cohort, id in cohort_to_id.items():
       n_samples = sum(cohorts == id)
       print(f"{cohort}: {n_samples} Samples (ID: {id})")
   
   return cohorts

# %%
base_path = os.path.dirname(os.getcwd()) 
base_path = os.path.join(base_path, 'code')
loader = DataLoader(base_path)
loader.load_all_data()

# %%
from new_structure.src.models.deep_surv import DeepSurvModel

# %%
import numpy as np
import pandas as pd
import itertools
from new_structure.src.models.deep_surv import DeepSurvModel
from sklearn.model_selection import LeaveOneGroupOut

# Lade die Daten
exprs = loader.common_genes_data['common_genes_knn_imputed.csv']
pdata = loader.merged_pdata_imputed['merged_imputed_pData.csv']

n_samples = len(pdata)
survival_data = np.zeros(n_samples, dtype={'names': ('time', 'status'), 'formats': ('f8', 'bool')})
survival_data['time'] = pdata['MONTH_TO_BCR'].values
survival_data['status'] = pdata['BCR_STATUS'].astype(bool).values
y = survival_data
X = exprs

cohorts = get_cohorts_from_index(X.index)

param_grid = {
   'hidden_layers': [[32,16], [64,32]],
   'learning_rate': [0.001, 0.0001],
   'batch_size': [32, 64],
   'n_epochs': [50]
}

results = []
param_names = param_grid.keys()
param_values = param_grid.values()
param_combinations = list(itertools.product(*param_values))

logo = LeaveOneGroupOut()

for params in param_combinations:
   param_dict = dict(zip(param_names, params))
   print(f"\nTraining with parameters: {param_dict}")
   
   fold_c_indices = []
   cohort_names = []
   
   # Leave-One-Group-Out cross validation
   for train_idx, test_idx in logo.split(X, y, groups=cohorts):
       cohort_name = X.index[test_idx[0]].split('.')[0]
       print(f"\nTesting on cohort {cohort_name}")
       
       # Split data
       X_train = X.iloc[train_idx]
       y_train = y[train_idx]
       X_test = X.iloc[test_idx]
       y_test = y[test_idx]
       
       # Train model
       model = DeepSurvModel(**param_dict)
       model.fit_model(X_train, y_train)
       
       # Evaluate on test set
       predictions = model.predict_model(X_test)
       c_index = model.calculate_c_index(y_test, predictions.flatten())  # Hier die Änderung
       fold_c_indices.append(c_index)
       cohort_names.append(cohort_name)
       
       print(f"Test cohort {cohort_name} C-index: {c_index:.4f}")
   
   # Calculate mean and std of c-index across cohorts
   mean_c_index = np.mean(fold_c_indices)
   std_c_index = np.std(fold_c_indices)
   
   print(f"\nMean C-index across cohorts: {mean_c_index:.4f} (±{std_c_index:.4f})")
   
   # Store results
   results.append({
       **param_dict,
       'mean_c_index': mean_c_index,
       'std_c_index': std_c_index,
       'cohort_scores': fold_c_indices,
       'cohort_names': cohort_names
   })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Sort by mean c-index
print("\nGrid Search Results:")
print(results_df.sort_values('mean_c_index', ascending=False))
# Out:
# Atlanta_2014_Long: 100 Samples (ID: 0)
# Belfast_2018_Jain: 248 Samples (ID: 1)
# CPC_GENE_2017_Fraser: 73 Samples (ID: 2)
# CPGEA_2020_Li: 120 Samples (ID: 3)
# CamCap_2016_Ross_Adams: 112 Samples (ID: 4)
# CancerMap_2017_Luca: 133 Samples (ID: 5)
# DKFZ_2018_Gerhauser: 82 Samples (ID: 6)
# MSKCC_2010_Taylor: 131 Samples (ID: 7)
# Stockholm_2016_Ross_Adams: 92 Samples (ID: 8)
#
# Training with parameters: {'hidden_layers': [32, 16], 'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 694.6953
# Epoch 10: Loss = 480.2270
# Epoch 20: Loss = 424.1550
# Epoch 30: Loss = 379.3379
# Epoch 40: Loss = 290.8111
# Test cohort Atlanta_2014_Long C-index: 0.6855
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 727.2180
# Epoch 10: Loss = 581.7438
# Epoch 20: Loss = 492.0078
# Epoch 30: Loss = 423.3386
# Epoch 40: Loss = 402.7075
# Test cohort Belfast_2018_Jain C-index: 0.6507
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 719.9620
# Epoch 10: Loss = 548.8331
# Epoch 20: Loss = 437.0196
# Epoch 30: Loss = 407.0728
# Epoch 40: Loss = 409.4727
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7848
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 702.8883
# Epoch 10: Loss = 498.2941
# Epoch 20: Loss = 421.8656
# Epoch 30: Loss = 363.5389
# Epoch 40: Loss = 404.1337
# Test cohort CPGEA_2020_Li C-index: 0.6787
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 817.3219
# Epoch 10: Loss = 588.1184
# Epoch 20: Loss = 461.1221
# Epoch 30: Loss = 453.9537
# Epoch 40: Loss = 368.8413
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7393
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 744.8252
# Epoch 10: Loss = 490.6044
# Epoch 20: Loss = 468.2120
# Epoch 30: Loss = 390.2498
# Epoch 40: Loss = 328.1848
# Test cohort CancerMap_2017_Luca C-index: 0.5921
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 753.6317
# Epoch 10: Loss = 493.1369
# Epoch 20: Loss = 440.1672
# Epoch 30: Loss = 407.5408
# Epoch 40: Loss = 343.5019
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8118
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 750.5735
# Epoch 10: Loss = 521.1614
# Epoch 20: Loss = 469.2125
# Epoch 30: Loss = 453.7590
# Epoch 40: Loss = 409.9729
# Test cohort MSKCC_2010_Taylor C-index: 0.6700
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 664.3129
# Epoch 10: Loss = 452.4197
# Epoch 20: Loss = 370.6800
# Epoch 30: Loss = 334.2112
# Epoch 40: Loss = 330.1259
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6786
#
# Mean C-index across cohorts: 0.6991 (±0.0644)
#
# Training with parameters: {'hidden_layers': [32, 16], 'learning_rate': 0.001, 'batch_size': 64, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 3218.2317
# Epoch 10: Loss = 2526.4851
# Epoch 20: Loss = 2196.3845
# Epoch 30: Loss = 2051.0391
# Epoch 40: Loss = 2128.6231
# Test cohort Atlanta_2014_Long C-index: 0.6491
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 3712.3421
# Epoch 10: Loss = 2915.0000
# Epoch 20: Loss = 2586.5238
# Epoch 30: Loss = 2549.6014
# Epoch 40: Loss = 2528.0688
# Test cohort Belfast_2018_Jain C-index: 0.6553
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 3873.8790
# Epoch 10: Loss = 3045.4983
# Epoch 20: Loss = 2846.1090
# Epoch 30: Loss = 2664.7604
# Epoch 40: Loss = 2461.9617
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7672
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 3464.6668
# Epoch 10: Loss = 2723.3012
# Epoch 20: Loss = 2434.6947
# Epoch 30: Loss = 2266.0872
# Epoch 40: Loss = 2135.8007
# Test cohort CPGEA_2020_Li C-index: 0.6661
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 3617.8448
# Epoch 10: Loss = 2971.8115
# Epoch 20: Loss = 2844.1967
# Epoch 30: Loss = 2524.0281
# Epoch 40: Loss = 2425.7986
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7265
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 3629.2599
# Epoch 10: Loss = 2845.4584
# Epoch 20: Loss = 2613.9283
# Epoch 30: Loss = 2418.3816
# Epoch 40: Loss = 2431.2034
# Test cohort CancerMap_2017_Luca C-index: 0.6331
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 3598.7929
# Epoch 10: Loss = 2938.4148
# Epoch 20: Loss = 2499.1147
# Epoch 30: Loss = 2408.1436
# Epoch 40: Loss = 2349.0054
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8210
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 3904.1561
# Epoch 10: Loss = 3060.5014
# Epoch 20: Loss = 2968.7672
# Epoch 30: Loss = 2622.8659
# Epoch 40: Loss = 2512.1367
# Test cohort MSKCC_2010_Taylor C-index: 0.6475
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 3386.8162
# Epoch 10: Loss = 2696.2935
# Epoch 20: Loss = 2395.1700
# Epoch 30: Loss = 2191.0524
# Epoch 40: Loss = 2084.1491
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6830
#
# Mean C-index across cohorts: 0.6943 (±0.0604)
#
# Training with parameters: {'hidden_layers': [32, 16], 'learning_rate': 0.0001, 'batch_size': 32, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 696.8497
# Epoch 10: Loss = 530.2243
# Epoch 20: Loss = 470.7435
# Epoch 30: Loss = 457.6587
# Epoch 40: Loss = 422.6085
# Test cohort Atlanta_2014_Long C-index: 0.6405
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 790.0618
# Epoch 10: Loss = 577.2806
# Epoch 20: Loss = 531.3150
# Epoch 30: Loss = 529.6040
# Epoch 40: Loss = 478.4254
# Test cohort Belfast_2018_Jain C-index: 0.6347
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 785.0678
# Epoch 10: Loss = 575.5359
# Epoch 20: Loss = 514.4527
# Epoch 30: Loss = 490.6302
# Epoch 40: Loss = 472.2624
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7370
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 733.2730
# Epoch 10: Loss = 542.9890
# Epoch 20: Loss = 513.1473
# Epoch 30: Loss = 465.9693
# Epoch 40: Loss = 473.3593
# Test cohort CPGEA_2020_Li C-index: 0.6813
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 787.7269
# Epoch 10: Loss = 613.6877
# Epoch 20: Loss = 541.5846
# Epoch 30: Loss = 532.2449
# Epoch 40: Loss = 487.1256
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7556
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 735.6866
# Epoch 10: Loss = 587.6748
# Epoch 20: Loss = 502.6885
# Epoch 30: Loss = 459.3577
# Epoch 40: Loss = 465.6171
# Test cohort CancerMap_2017_Luca C-index: 0.6108
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 754.4734
# Epoch 10: Loss = 564.2080
# Epoch 20: Loss = 522.2056
# Epoch 30: Loss = 444.4383
# Epoch 40: Loss = 454.2724
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8177
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 776.6071
# Epoch 10: Loss = 599.7655
# Epoch 20: Loss = 549.1648
# Epoch 30: Loss = 514.9928
# Epoch 40: Loss = 501.3538
# Test cohort MSKCC_2010_Taylor C-index: 0.6759
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 689.8651
# Epoch 10: Loss = 488.9849
# Epoch 20: Loss = 455.3077
# Epoch 30: Loss = 403.6245
# Epoch 40: Loss = 423.8323
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6816
#
# Mean C-index across cohorts: 0.6928 (±0.0622)
#
# Training with parameters: {'hidden_layers': [32, 16], 'learning_rate': 0.0001, 'batch_size': 64, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 3242.6882
# Epoch 10: Loss = 2505.2748
# Epoch 20: Loss = 2514.0934
# Epoch 30: Loss = 2403.2599
# Epoch 40: Loss = 2215.8856
# Test cohort Atlanta_2014_Long C-index: 0.6335
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 3703.0464
# Epoch 10: Loss = 2885.5587
# Epoch 20: Loss = 2903.4539
# Epoch 30: Loss = 2810.9338
# Epoch 40: Loss = 2689.2287
# Test cohort Belfast_2018_Jain C-index: 0.6305
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 3668.6953
# Epoch 10: Loss = 2960.8670
# Epoch 20: Loss = 2841.8882
# Epoch 30: Loss = 2734.0500
# Epoch 40: Loss = 2707.7260
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7453
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 3615.2733
# Epoch 10: Loss = 2855.2106
# Epoch 20: Loss = 2574.7082
# Epoch 30: Loss = 2642.2174
# Epoch 40: Loss = 2487.3660
# Test cohort CPGEA_2020_Li C-index: 0.7023
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 3767.7239
# Epoch 10: Loss = 2991.6165
# Epoch 20: Loss = 2809.2130
# Epoch 30: Loss = 2570.6339
# Epoch 40: Loss = 2665.1619
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7549
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 3743.8306
# Epoch 10: Loss = 2991.3068
# Epoch 20: Loss = 2808.0418
# Epoch 30: Loss = 2581.8488
# Epoch 40: Loss = 2769.5513
# Test cohort CancerMap_2017_Luca C-index: 0.5738
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 3799.7097
# Epoch 10: Loss = 2953.3952
# Epoch 20: Loss = 2874.5269
# Epoch 30: Loss = 2633.2318
# Epoch 40: Loss = 2494.7134
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8002
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 3849.8741
# Epoch 10: Loss = 3254.0492
# Epoch 20: Loss = 3009.0669
# Epoch 30: Loss = 2770.5239
# Epoch 40: Loss = 2793.1192
# Test cohort MSKCC_2010_Taylor C-index: 0.7030
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 3328.0020
# Epoch 10: Loss = 2759.0158
# Epoch 20: Loss = 2490.1812
# Epoch 30: Loss = 2445.5452
# Epoch 40: Loss = 2407.7150
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6867
#
# Mean C-index across cohorts: 0.6923 (±0.0666)
#
# Training with parameters: {'hidden_layers': [64, 32], 'learning_rate': 0.001, 'batch_size': 32, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 694.0590
# Epoch 10: Loss = 440.1001
# Epoch 20: Loss = 409.9999
# Epoch 30: Loss = 339.5108
# Epoch 40: Loss = 256.5906
# Test cohort Atlanta_2014_Long C-index: 0.6592
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 788.1266
# Epoch 10: Loss = 506.6087
# Epoch 20: Loss = 442.3041
# Epoch 30: Loss = 439.1879
# Epoch 40: Loss = 372.2065
# Test cohort Belfast_2018_Jain C-index: 0.6387
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 737.6528
# Epoch 10: Loss = 518.8781
# Epoch 20: Loss = 414.6751
# Epoch 30: Loss = 420.3938
# Epoch 40: Loss = 420.4745
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7557
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 713.9227
# Epoch 10: Loss = 474.7883
# Epoch 20: Loss = 410.6660
# Epoch 30: Loss = 355.4696
# Epoch 40: Loss = 331.8037
# Test cohort CPGEA_2020_Li C-index: 0.6865
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 748.0403
# Epoch 10: Loss = 504.2252
# Epoch 20: Loss = 473.8880
# Epoch 30: Loss = 382.7788
# Epoch 40: Loss = 404.4473
# Test cohort CamCap_2016_Ross_Adams C-index: 0.6818
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 745.1450
# Epoch 10: Loss = 422.4195
# Epoch 20: Loss = 341.6014
# Epoch 30: Loss = 336.9220
# Epoch 40: Loss = 321.8372
# Test cohort CancerMap_2017_Luca C-index: 0.5194
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 731.6665
# Epoch 10: Loss = 464.8832
# Epoch 20: Loss = 431.4941
# Epoch 30: Loss = 412.8367
# Epoch 40: Loss = 339.0293
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8243
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 762.0936
# Epoch 10: Loss = 492.2832
# Epoch 20: Loss = 414.9090
# Epoch 30: Loss = 378.1501
# Epoch 40: Loss = 350.9923
# Test cohort MSKCC_2010_Taylor C-index: 0.6669
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 675.2083
# Epoch 10: Loss = 443.8146
# Epoch 20: Loss = 371.4540
# Epoch 30: Loss = 332.8240
# Epoch 40: Loss = 319.7254
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6621
#
# Mean C-index across cohorts: 0.6772 (±0.0781)
#
# Training with parameters: {'hidden_layers': [64, 32], 'learning_rate': 0.001, 'batch_size': 64, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 3352.5803
# Epoch 10: Loss = 2424.3997
# Epoch 20: Loss = 2323.7816
# Epoch 30: Loss = 1960.4951
# Epoch 40: Loss = 2020.9847
# Test cohort Atlanta_2014_Long C-index: 0.6185
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 3807.6782
# Epoch 10: Loss = 2986.8173
# Epoch 20: Loss = 2502.0073
# Epoch 30: Loss = 2407.6895
# Epoch 40: Loss = 2475.1394
# Test cohort Belfast_2018_Jain C-index: 0.6600
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 3792.4737
# Epoch 10: Loss = 2836.6088
# Epoch 20: Loss = 2649.2041
# Epoch 30: Loss = 2358.5796
# Epoch 40: Loss = 2319.8906
# Test cohort CPC_GENE_2017_Fraser C-index: 0.8046
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 3396.5649
# Epoch 10: Loss = 2391.8609
# Epoch 20: Loss = 2291.3040
# Epoch 30: Loss = 2084.5351
# Epoch 40: Loss = 2167.7772
# Test cohort CPGEA_2020_Li C-index: 0.6658
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 3659.3809
# Epoch 10: Loss = 2858.3932
# Epoch 20: Loss = 2546.4830
# Epoch 30: Loss = 2298.7169
# Epoch 40: Loss = 2270.0789
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7156
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 3787.2706
# Epoch 10: Loss = 2921.4169
# Epoch 20: Loss = 2466.0815
# Epoch 30: Loss = 2288.0285
# Epoch 40: Loss = 2335.9310
# Test cohort CancerMap_2017_Luca C-index: 0.6006
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 3773.8329
# Epoch 10: Loss = 2857.7512
# Epoch 20: Loss = 2593.3957
# Epoch 30: Loss = 2310.4485
# Epoch 40: Loss = 2253.7968
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8393
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 3901.5963
# Epoch 10: Loss = 2976.0943
# Epoch 20: Loss = 2557.6658
# Epoch 30: Loss = 2548.8698
# Epoch 40: Loss = 2298.5406
# Test cohort MSKCC_2010_Taylor C-index: 0.6960
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 3394.1258
# Epoch 10: Loss = 2544.8772
# Epoch 20: Loss = 2264.1801
# Epoch 30: Loss = 2167.0566
# Epoch 40: Loss = 2000.7571
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6499
#
# Mean C-index across cohorts: 0.6945 (±0.0761)
#
# Training with parameters: {'hidden_layers': [64, 32], 'learning_rate': 0.0001, 'batch_size': 32, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 682.9402
# Epoch 10: Loss = 451.6170
# Epoch 20: Loss = 408.5965
# Epoch 30: Loss = 373.1748
# Epoch 40: Loss = 340.4337
# Test cohort Atlanta_2014_Long C-index: 0.6595
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 733.8572
# Epoch 10: Loss = 556.0472
# Epoch 20: Loss = 522.2906
# Epoch 30: Loss = 485.2325
# Epoch 40: Loss = 427.1735
# Test cohort Belfast_2018_Jain C-index: 0.6411
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 778.0575
# Epoch 10: Loss = 548.9581
# Epoch 20: Loss = 513.3675
# Epoch 30: Loss = 455.4514
# Epoch 40: Loss = 436.2821
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7796
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 712.8818
# Epoch 10: Loss = 504.0104
# Epoch 20: Loss = 447.6184
# Epoch 30: Loss = 433.9798
# Epoch 40: Loss = 396.2458
# Test cohort CPGEA_2020_Li C-index: 0.6803
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 761.6591
# Epoch 10: Loss = 566.9251
# Epoch 20: Loss = 507.9284
# Epoch 30: Loss = 487.3046
# Epoch 40: Loss = 453.0821
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7231
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 718.3642
# Epoch 10: Loss = 514.3949
# Epoch 20: Loss = 467.6303
# Epoch 30: Loss = 427.3379
# Epoch 40: Loss = 419.5321
# Test cohort CancerMap_2017_Luca C-index: 0.6628
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 756.6127
# Epoch 10: Loss = 513.5726
# Epoch 20: Loss = 425.6494
# Epoch 30: Loss = 416.7819
# Epoch 40: Loss = 394.9311
# Test cohort DKFZ_2018_Gerhauser C-index: 0.8310
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 800.2177
# Epoch 10: Loss = 538.0105
# Epoch 20: Loss = 522.3950
# Epoch 30: Loss = 497.1867
# Epoch 40: Loss = 487.8259
# Test cohort MSKCC_2010_Taylor C-index: 0.6514
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 671.3878
# Epoch 10: Loss = 451.5745
# Epoch 20: Loss = 408.9371
# Epoch 30: Loss = 400.2598
# Epoch 40: Loss = 344.2762
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.7002
#
# Mean C-index across cohorts: 0.7032 (±0.0607)
#
# Training with parameters: {'hidden_layers': [64, 32], 'learning_rate': 0.0001, 'batch_size': 64, 'n_epochs': 50}
#
# Testing on cohort Atlanta_2014_Long
# Epoch 0: Loss = 3425.9057
# Epoch 10: Loss = 2558.2061
# Epoch 20: Loss = 2323.5234
# Epoch 30: Loss = 2344.3149
# Epoch 40: Loss = 2200.5851
# Test cohort Atlanta_2014_Long C-index: 0.6514
#
# Testing on cohort Belfast_2018_Jain
# Epoch 0: Loss = 3726.5973
# Epoch 10: Loss = 2898.1960
# Epoch 20: Loss = 2666.6201
# Epoch 30: Loss = 2517.0048
# Epoch 40: Loss = 2450.7404
# Test cohort Belfast_2018_Jain C-index: 0.6229
#
# Testing on cohort CPC_GENE_2017_Fraser
# Epoch 0: Loss = 3840.0217
# Epoch 10: Loss = 2974.4912
# Epoch 20: Loss = 2952.4683
# Epoch 30: Loss = 2741.7547
# Epoch 40: Loss = 2739.9582
# Test cohort CPC_GENE_2017_Fraser C-index: 0.7297
#
# Testing on cohort CPGEA_2020_Li
# Epoch 0: Loss = 3409.2714
# Epoch 10: Loss = 2740.6970
# Epoch 20: Loss = 2480.7364
# Epoch 30: Loss = 2364.5389
# Epoch 40: Loss = 2517.3082
# Test cohort CPGEA_2020_Li C-index: 0.6642
#
# Testing on cohort CamCap_2016_Ross_Adams
# Epoch 0: Loss = 3683.2447
# Epoch 10: Loss = 2884.5602
# Epoch 20: Loss = 2608.9715
# Epoch 30: Loss = 2681.6400
# Epoch 40: Loss = 2350.5330
# Test cohort CamCap_2016_Ross_Adams C-index: 0.7089
#
# Testing on cohort CancerMap_2017_Luca
# Epoch 0: Loss = 3768.8182
# Epoch 10: Loss = 2797.2456
# Epoch 20: Loss = 2780.4434
# Epoch 30: Loss = 2482.1306
# Epoch 40: Loss = 2572.2215
# Test cohort CancerMap_2017_Luca C-index: 0.5784
#
# Testing on cohort DKFZ_2018_Gerhauser
# Epoch 0: Loss = 3806.8208
# Epoch 10: Loss = 2909.9093
# Epoch 20: Loss = 2742.8994
# Epoch 30: Loss = 2569.9261
# Epoch 40: Loss = 2575.7161
# Test cohort DKFZ_2018_Gerhauser C-index: 0.7752
#
# Testing on cohort MSKCC_2010_Taylor
# Epoch 0: Loss = 3815.8716
# Epoch 10: Loss = 3000.3867
# Epoch 20: Loss = 2799.0293
# Epoch 30: Loss = 2763.4805
# Epoch 40: Loss = 2643.2412
# Test cohort MSKCC_2010_Taylor C-index: 0.7158
#
# Testing on cohort Stockholm_2016_Ross_Adams
# Epoch 0: Loss = 3266.2378
# Epoch 10: Loss = 2544.8949
# Epoch 20: Loss = 2446.7149
# Epoch 30: Loss = 2326.3793
# Epoch 40: Loss = 2335.0999
# Test cohort Stockholm_2016_Ross_Adams C-index: 0.6695
#
# Mean C-index across cohorts: 0.6796 (±0.0562)
#
# Grid Search Results:
#   hidden_layers  learning_rate  batch_size  n_epochs  mean_c_index  \
# 6      [64, 32]         0.0001          32        50      0.703233
# 0      [32, 16]         0.0010          32        50      0.699070
# 5      [64, 32]         0.0010          64        50      0.694494
# 1      [32, 16]         0.0010          64        50      0.694301
# 2      [32, 16]         0.0001          32        50      0.692781
# 3      [32, 16]         0.0001          64        50      0.692256
# 7      [64, 32]         0.0001          64        50      0.679558
# 4      [64, 32]         0.0010          32        50      0.677179
#
#    std_c_index                                      cohort_scores  \
# 6     0.060708  [0.6595375722543353, 0.6411117898594991, 0.779...
# 0     0.064411  [0.6855491329479769, 0.6506821421299125, 0.784...
# 5     0.076098  [0.6184971098265896, 0.6600488698839341, 0.804...
# 1     0.060382  [0.6491329479768786, 0.6552636937487274, 0.767...
# 2     0.062239  [0.6404624277456648, 0.6346976175931582, 0.737...
# 3     0.066597  [0.6335260115606937, 0.6305233150071269, 0.745...
# 7     0.056185  [0.6514450867052023, 0.6228873956424353, 0.729...
# 4     0.078136  [0.6592485549132948, 0.6386682956627978, 0.755...
#
#                                         cohort_names
# 6  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 0  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 5  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 1  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 2  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 3  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 7  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
# 4  [Atlanta_2014_Long, Belfast_2018_Jain, CPC_GEN...
